# %% [markdown]
# <a href="https://colab.research.google.com/github/fmc60/BTE320/blob/main/BTE_320_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('hello')
# Out:
# hello

# %%
x = 0
if(x<1): print('A')
else: print('B')
# Out:
# A
